# %%
# Import required modules
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
from datetime import date

# %%
# Making request to the site and parsing as beautifulsoup object
r = requests.get("https://www.shawacademy.com/courses")
s = BeautifulSoup(r.text, "lxml")

# %%
# Extract title
title = s.find_all("div", "course-name")
title = [title.text for title in title]

# Extract course link
courseLink = s.find_all("div", "course-name")
courseLink = [lnk.find("a").get("href") for lnk in courseLink]

# Extract unit sale
unitSold = s.find_all("div", class_="enroll-count")
unitSold = [sld.text.strip() for sld in unitSold]

# Extract course rating
rating = s.find_all("div", class_="rating")
rating = [rt.find("p").text.strip() for rt in rating]

# Extract course description
des = s.find_all("div", "course-description")
des = [ds.find("p").text.strip() for ds in des]

# %%
# Create a df off extracted variables
df = pd.DataFrame({
    "courseTitle":title,
    "courseLink":courseLink,
    "unitSold":unitSold,
    "rating":rating,
    "description":des
})

# Create absolute course links
df.courseLink = "https://www.shawacademy.com" + df.courseLink

# %%
# Clean unitSold and cast the required variables into appropriate one
df.unitSold = df.unitSold.str.replace("Graduates", "").str.replace(",", "").astype("int")
df.rating = df.rating.astype("float")

# %%
# Let's have a look at our final data
df.head(10)
# Out:
#                     courseTitle  \
# 0                   Photography
# 1  iPhone & Android Photography
# 2  Video Editing and Production
# 3           Wedding Photography
# 4               Adobe Lightroom
# 5              Online Photoshop
# 6             Digital Marketing
# 7        Social Media Marketing
# 8              Creative Writing
# 9       SEO & Digital Marketing
#
#                                           courseLink  unitSold  rating  \
# 0  https://www.shawacademy.com/courses/photograph...   1503225     4.8
# 1  https://www.shawacademy.com/courses/photograph...    177739     4.6
# 2  https://www.shawacademy.com/courses/photograph...     53755     4.2
# 3  https://www.shawacademy.com/courses/photograph...     32749     4.6
# 4  https://www.shawacademy.com/courses/photograph...     80128     4.6
# 5  https://www.shawacademy.com/courses/photograph...    211687     4.8
# 6  https://www.shawacademy.com/courses/marketing/...    471518     4.9
# 7  https://www.shawacademy.com/courses/marketing/...    341432     4.8
# 8  https://www.shawacademy.com/courses/marketing/...     37268     4.9
# 9  https://www.shawacademy.com/courses/marketing/...     25435     4.8
#
#                                          description
# 0  Become a professional photographer with comple...
# 1  Learn how to take high quality, amazing shots ...
# 2  Discover everything you need to know about vid...
# 3  Learn how to take the perfect wedding portrait...
# 4  Learn how to use Adobe Lightroom and discover ...
# 5  Master the fundamentals of Photoshop, from the...
# 6  Understand different marketing channels and ta...
# 7  Learn how to build and launch an effective soc...
# 8  Take your prose to the next level and discover...
# 9  Unlock the secrets to growing your visibility ...

# %%
# Today's date to save the daata
today = pd.to_datetime("today").strftime("%d_%b_%y")
df.to_excel(f"shawAcademy_{today}.xlsx", index=None)
